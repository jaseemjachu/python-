# %% [markdown]
# <a href="https://colab.research.google.com/github/jaseemjachu/python-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b248068f-9bcc-4d99-8edd-ad47c5aa3759" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b248068f-9bcc-4d99-8edd-ad47c5aa3759">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv("SOCR-HeightWeight.csv")
import plotly.express as px
height=df['Height(Inches)']
weight=df['Weight(Pounds)']
print("Mean Height of the class: ",height.mean())
print("Mean WEeight of the class: ",weight.mean())
print("Median Height of the class: ",height.median())
print("Median Weight of the class: ",weight.median())
print("Mode Height of the class: ",height.mode())
print("Mode Weight of the class: ",weight.mode())

px.scatter(height,weight)
#plt.bar(height,weight)
figure=px.scatter(height,weight)
figure.show()
# Out:
# Mean Height of the class:  67.99311359679999
# Mean WEeight of the class:  127.07942116080001
# Median Height of the class:  67.9957
# Median Weight of the class:  127.15775
# Mode Height of the class:  0     65.65796
# 1     67.34629
# 2     67.41672
# 3     67.94061
# 4     67.97769
# 5     67.98509
# 6     68.30287
# 7     68.92380
# 8     68.93456
# 9     68.97830
# 10    70.04724
# dtype: float64
# Mode Weight of the class:  0    124.7975
# dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-753d68c2-627f-4bf3-8504-c7e755e182f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-753d68c2-627f-4bf3-8504-c7e755e182f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6f2c0f02-00dc-4199-b521-20ab4b408f8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f2c0f02-00dc-4199-b521-20ab4b408f8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1=pd.read_csv("class1.csv")
df2=pd.read_csv("class1.csv")
fig1=px.scatter(df1,x="student number",y="marks",title="class1")
fig2=px.scatter(df2,x="student number",y="marks",title="class2")
marks1=df1["marks"]
average1=marks1.mean()
average2=marks2.mean()
print("class1 average")
